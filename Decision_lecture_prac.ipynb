# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn import tree
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

DecisionTreeClfModel= DecisionTreeClassifier()

x_train = [[0.1,1,0.4],
           [0.2,0.8,0.5],
           [0.3,0.6,0.6],
           [0.4,0.4,0.7],
           [0.5,0.1,0.9],
           [0.6,0.1,0.8],
           [0.7,0.3,0.5],
           [0.8,0.5,0.2],
           [0.9,0.4,0.1],
           [1,0.1,0.4]]
y_train = [[0],[1],[1],[0],[1],[0],[0],[1],[0],[1]]

DecisionTreeClfModel.fit(x_train,y_train)

x_test = [[1,0,0.5]]
x_result = DecisionTreeClfModel.predict(x_test)

print(x_result)
# Out:
# [1]

# %%
# labels = df_iris_X.columns
labels = ['성격?','경재력?','외모?']
# 성공 - 1, 실패 - 2
y_labels = ['성공', '실패']

#

graph = Source(tree.export_graphviz(DecisionTreeClfModel ,feature_names = labels, class_names = y_labels , filled = True))
display(SVG(graph.pipe(format='svg')))

# %%
labels = ['성격','경제력','외모']

y_labels = ['성공', '실패']

# graph = Source(tree.export_graphviz(DecisionTreeClfModel ,feature_names = labels, class_names = y_labels , max_depth = 3, filled = True))
graph = Source(tree.export_graphviz(DecisionTreeClfModel ,feature_names = labels, class_names = y_labels , filled = True))
display(SVG(graph.pipe(format='svg')))
