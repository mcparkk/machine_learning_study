# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filename = '/content/MLK_speech_August28_1963.txt'
data = pd.read_csv(filename,sep='|')
data.head(100)
# Out:
#                               Transcript of speech by
# 0                          Dr. Martin Luther King Jr.
# 1   August 28, 1963. Lincoln Memorial in Washingto...
# 2   I am happy to join with you today in what will...
# 3   Five score years ago a great American in whose...
# 4   But one hundred years later the Negro is still...
# 5   One hundred years later the Negro lives on a l...
# 6   One hundred years later the Negro is still lan...
# 7   We all have come to this hallowed spot to remi...
# 8   There will be neither rest nor tranquility in ...
# 9   We must forever conduct our struggle on the hi...
# 10  And the marvelous new militarism which has eng...
# 11  So even though we face the difficulties of tod...
# 12  I have a dream that one day this nation will r...
# 13  I have a dream that one day on the red hills o...
# 14  I have a dream that one day even the state of ...
# 15  I have a dream that little children will one d...
# 16                              I have a dream today.
# 17  I have a dream that one day down in Alabama, w...
# 18                              I have a dream today.
# 19  I have a dream that one day every valley shall...
# 20  This is our hope. This is the faith that I go ...
# 21  And I say to you today my friends, let freedom...
# 22  Let freedom ring from the snow capped Rockies ...
# 23  Let freedom ring from the curvaceous slopes of...
# 24  But not only there; let freedom ring from the ...
# 25  Let freedom ring from Lookout Mountain in Tenn...
# 26  Let freedom ring from every hill and molehill ...
# 27  And when this happens, when we allow freedom t...

# %%
#!/usr/bin/env python

import os
from os import path
from wordcloud import WordCloud

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = open(path.join(d, 'MLK_speech_August28_1963.txt')).read()

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
